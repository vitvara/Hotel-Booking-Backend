# %%
import pandas as pd

# %%
DB_FILE_PATH = "hotel.db"
# Out:
# [{'room_id': 1,
#   'room_number': 1,
#   'building': 'A',
#   'floor': 1,
#   'bed': 2,
#   'max_guest': 2,
#   'price': 4000,
#   'status': 'avaliable',
#   'type': 'Suite'},
#  {'room_id': 2,
#   'room_number': 2,
#   'building': 'A',
#   'floor': 1,
#   'bed': 2,
#   'max_guest': 2,
#   'price': 4000,
#   'status': 'avaliable',
#   'type': 'Suite'},
#  {'room_id': 3,
#   'room_number': 3,
#   'building': 'A',
#   'floor': 1,
#   'bed': 2,
#   'max_guest': 2,
#   'price': 4000,
#   'status': 'avaliable',
#   'type': 'Suite'},
#  {'room_id': 4,
#   'room_number': 4,
#   'building': 'A',
#   'floor': 1,
#   'bed': 2,
#   'max_guest': 2,
#   'price': 4000,
#   'status': 'avaliable',
#   'type': 'Suite'},
#  {'room_id': 5,
#   'room_number': 5,
#   'building': 'A',
#   'floor': 1,
#   'bed': 2,
#   'max_guest': 2,
#   'price': 4000,
#   'status': 'avaliable',
#   'type': 'Suite'},
#  {'room_id': 6,
#   'room_number': 6,
#   'building': 'A',
#   'floor': 1,
#   'bed': 2,
# ...
